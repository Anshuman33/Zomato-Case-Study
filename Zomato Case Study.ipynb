# %%
#import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline #to display graphs inline of jupyter notebook
# Out:
# UsageError: unrecognized arguments: #to display graphs inline of jupyter notebook

# %% [markdown]
# #### About Zomato
# Zomato is an Indian restaurant search and discovery service founded in 2008 by Deepinder Goyal and Pankaj Chaddah. It currently operates in 24 countries. It provides information and reviews of restaurants, including images of menus where the restaurant does not have its own website and also online delivery.

# %% [markdown]
# #### Data Context
# The basic idea of analyzing the Zomato dataset is to get a fair idea about the factors affecting the establishment of different types of restaurants at different places in Bengaluru. This Zomato data aims at analyzing demography of the location. Most importantly it will help new restaurants in deciding their theme, menus, cuisine, cost, etc for a particular location. It also aims at finding similarity between neighborhoods of Bengaluru on the basis of food.

# %% [markdown]
# __Data Dictionary:__
#
# - url - contains the url of the restaurant in the zomato website
# - address - contains the address of the restaurant in Bengaluru
# - name - contains the name of the restaurant
# - online_order - whether online ordering is available in the restaurant or not
# - book_table - table book option available or not
# - rate - contains the overall rating of the restaurant out of 5
# - votes - contains total number of rating for the restaurant as of the above mentioned date
# - phone - contains the phone number of the restaurant
# - location - contains the neighborhood in which the restaurant is located
# - rest_type - restaurant type
# - dish_liked - dishes people liked in the restaurant
# - cuisines - food styles, separated by comma
# - approx_cost(for two people) - contains the approximate cost for meal for two people
# - reviews_list - list of tuples containing reviews for the restaurant, each tuple consists of two values, rating and review by the customer
# - menu_item - contains list of menus available in the restaurant
# - listed_in(type) - type of meal
# - listed_in(city) - contains the neighborhood in which the restaurant is listed

# %% [markdown]
# #### 0. Import the Library

# %%
#import numpy, pandas, matplotlib, seaborn package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# __1. Load the Data__

# %%
zom=pd.read_csv("zomato.csv")
zom
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# 5      https://www.zomato.com/bangalore/timepass-dinn...
# 6      https://www.zomato.com/bangalore/rosewood-inte...
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 8      https://www.zomato.com/bangalore/penthouse-caf...
# 9      https://www.zomato.com/bangalore/smacznego-ban...
# 10     https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11     https://www.zomato.com/bangalore/cafe-shuffle-...
# 12     https://www.zomato.com/bangalore/the-coffee-sh...
# 13     https://www.zomato.com/bangalore/caf-eleven-ba...
# 14     https://www.zomato.com/SanchurroBangalore?cont...
# 15     https://www.zomato.com/bangalore/cafe-vivacity...
# 16     https://www.zomato.com/bangalore/catch-up-ino-...
# 17     https://www.zomato.com/bangalore/kirthis-birya...
# 18     https://www.zomato.com/bangalore/t3h-cafe-bana...
# 19     https://www.zomato.com/bangalore/360-atoms-res...
# 20     https://www.zomato.com/bangalore/the-vintage-c...
# 21     https://www.zomato.com/bangalore/woodee-pizza-...
# 22     https://www.zomato.com/bangalore/cafe-coffee-d...
# 23     https://www.zomato.com/bangalore/my-tea-house-...
# 24     https://www.zomato.com/bangalore/hide-out-cafe...
# 25     https://www.zomato.com/bangalore/cafe-nova-ban...
# 26     https://www.zomato.com/bangalore/coffee-tindi-...
# 27     https://www.zomato.com/bangalore/sea-green-caf...
# 28     https://www.zomato.com/bangalore/cuppa-1-banas...
# 29     https://www.zomato.com/bangalore/srinathjis-ca...
# ...                                                  ...
# 51687  https://www.zomato.com/bangalore/red-rhino-whi...
# 51688  https://www.zomato.com/bangalore/ji-hazoor-whi...
# 51689  https://www.zomato.com/bangalore/hq-whitefield...
# 51690  https://www.zomato.com/bangalore/biere-societe...
# 51691  https://www.zomato.com/bangalore/uno-chicago-b...
# 51692  https://www.zomato.com/bangalore/amoeba-sports...
# 51693  https://www.zomato.com/bangalore/one-for-the-r...
# 51694  https://www.zomato.com/WhitefieldSocial?contex...
# 51695  https://www.zomato.com/bangalore/the-whitefiel...
# 51696  https://www.zomato.com/bangalore/the-irish-hou...
# 51697  https://www.zomato.com/bangalore/shizusan-shop...
# 51698  https://www.zomato.com/bangalore/kava-kitchen-...
# 51699  https://www.zomato.com/bangalore/harrys-bar-ca...
# 51700  https://www.zomato.com/bangalore/bar-bar-white...
# 51701  https://www.zomato.com/bangalore/the-beer-cafe...
# 51702  https://www.zomato.com/bangalore/pablos-gastro...
# 51703  https://www.zomato.com/bangalore/olivers-pub-d...
# 51704  https://www.zomato.com/bangalore/smaaash-white...
# 51705  https://www.zomato.com/bangalore/izakaya-gastr...
# 51706  https://www.zomato.com/bangalore/red-glow-whit...
# 51707  https://www.zomato.com/bangalore/m-bar-bengalu...
# 51708  https://www.zomato.com/bangalore/keys-cafe-key...
# 51709  https://www.zomato.com/bangalore/the-farm-hous...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5      37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6      19/1, New Timberyard Layout, Beside Satellite ...
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 8      1, 30th Main Road, 3rd Stage, Banashankari, Ba...
# 9      2470, 21 Main Road, 25th Cross, Banashankari, ...
# 10     12,29 Near PES University Back Gate, D'Souza N...
# 11     941, 3rd FLOOR, 21st Main, 22nd Cross, Banasha...
# 12         6th Block, 3rd Stage, Banashankari, Bangalore
# 13     111, Sapphire Toys Building, 100 Feet Ring Roa...
# 14     1112, Next to KIMS Medical College, 17th Cross...
# 15     2303, 21st Cross, K R Road, 2nd Stage, Banasha...
# 16     241, 4th Floor, 100 Feet Ring Road, Opposite K...
# 17     405, 24th Cross, 9th Main, 2nd Stage, Banashan...
# 18     504, CJ Venkata Das Road, Padmanabhangar, 2nd ...
# 19     47, 48 &49, 3Rd Floor, 21st Main Road, 2nd Sta...
# 20     146, 50 ft Road, 3rd Phase, 3rd Stage, Near Ka...
# 21     3353, 2nd Cross, Opposite Auden School, Hosker...
# 22     SRF Complex, Near BDA Complex, Kathreguppe Mai...
# 23     224/Y, 4th Phase, 7th Block, 100 Feet Ring Roa...
# 24     775/1, Opposite Gupta Collage, 7th Block, 3rd ...
# 25     101, Water Tank Road, 2nd Block, 3rd Stage, Ba...
# 26     27th Cross Rd, Banashankari Stage II, Banashan...
# 27     1036, Srinidhi Plaza, 3rd floor, Above Nilgiri...
# 28     940, Shantha Complex, 20th Main, 2nd Stage, Ba...
# 29     112, Bull Temple Road,next to more Basavanagud...
# ...                                                  ...
# 51687  4th Floor, Uptown Square, Seegehalli, Near All...
# 51688  TR 9, 4th Floor, Plot 95, EPIP Zone, Near Vaid...
# 51689  75, Inorbit Mall, EPIP Area, Road 7, Whitefiel...
# 51690  223-1, ITPL Main Road, Sadarmangala, KR Puram ...
# 51691  Shop FB-02, Upper Ground Floor, Prestige Shant...
# 51692  Third Floor, Ascendas Park Square, ITPL Main R...
# 51693  87/2A & 87/3, SH 35, Seegehalli, Whitefield, B...
# 51694  29, Ground Floor, Phoenix Market City, Whitefi...
# 51695          The Waverly Hotels, Whitefield, Bangalore
# 51696  TF-01A, Level 3, VR Mall, Mahadevpura, Whitefi...
# 51697  Level 2, Phoenix Marketcity, Mahadevpura, Whit...
# 51698  3-A1, Kundanahalli Main Road, Mahadevpura, Opp...
# 51699  S-10, Level 2, Phoenix Market City, Whitefield...
# 51700  Level 2, Phoenix Marketcity, Whitefield, Banga...
# 51701  Unit 4A - 4B, Upper Ground Floor, VR Bengaluru...
# 51702  2, Graphite India Road, Doddanekundi Industria...
# 51703  ITPL Ascendas Park Square Mall, ITPL, First Fl...
# 51704  2nd Floor, Phoenix Market City, Whitefield, Ba...
# 51705  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 51706  Poornima Complex, Dodsworth Layout, Whitefield...
# 51707  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 51708  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51710  2E2, 4th Cross Road, Devasandra Industrial Est...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# 5                                        Timepass Dinner          Yes
# 6        Rosewood International Hotel - Bar & Restaurant           No
# 7                                                 Onesta          Yes
# 8                                         Penthouse Cafe          Yes
# 9                                              Smacznego          Yes
# 10     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes
# 11                                          Cafe Shuffle          Yes
# 12                                      The Coffee Shack          Yes
# 13                                            Caf-Eleven           No
# 14                                       San Churro Cafe          Yes
# 15                                         Cafe Vivacity          Yes
# 16                                          Catch-up-ino          Yes
# 17                                      Kirthi's Biryani          Yes
# 18                                              T3H Cafe           No
# 19                         360 Atoms Restaurant And Cafe          Yes
# 20                                      The Vintage Cafe          Yes
# 21                                          Woodee Pizza          Yes
# 22                                       Cafe Coffee Day           No
# 23                                          My Tea House          Yes
# 24                                         Hide Out Cafe           No
# 25                                             CAFE NOVA           No
# 26                                          Coffee Tindi          Yes
# 27                                        Sea Green Cafe           No
# 28                                                 Cuppa           No
# 29                                      Srinathji's Cafe           No
# ...                                                  ...          ...
# 51687                                          Red Rhino          Yes
# 51688                                          Ji Hazoor          Yes
# 51689                                                 HQ           No
# 51690                                     Biere Societee           No
# 51691                            Uno Chicago Bar & Grill           No
# 51692                                  Amoeba Sports Bar          Yes
# 51693                                   One For The Road          Yes
# 51694                                  Whitefield Social          Yes
# 51695             The Whitefield Arms Pub & Microbrewery          Yes
# 51696                                    The Irish House           No
# 51697                           Shizusan Shophouse & Bar          Yes
# 51698         Kava Kitchen & Bar - Fairfield by Marriott           No
# 51699                                 Harry's Bar + Cafe          Yes
# 51700                                            BAR BAR           No
# 51701                                      The Beer Cafe          Yes
# 51702                                  Pablo's Gastrobar           No
# 51703                               Oliver's Pub & Diner          Yes
# 51704                                            Smaaash           No
# 51705                                 Izakaya Gastro Pub          Yes
# 51706                                           Red Glow           No
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51709                         The Farm House Bar n Grill           No
# 51710                                       Topsy Turvey           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# 5             No   3.8/5    286  +91 9980040002\r\n+91 9980063005
# 6             No   3.6/5      8    +91 9731716688\r\n080 26740366
# 7            Yes   4.6/5   2556      080 48653961\r\n080 48655715
# 8             No   4.0/5    324  +91 8884135549\r\n+91 9449449316
# 9             No   4.2/5    504  +91 9945230807\r\n+91 9743804471
# 10            No   4.1/5    402    080 26724489\r\n+91 7406048982
# 11           Yes   4.2/5    150                    +91 9742166777
# 12           Yes   4.2/5    164                    +91 9731644212
# 13            No   4.0/5    424                      080 49577715
# 14            No   3.8/5    918                    +91 9663487993
# 15            No   3.8/5     90    080 26768182\r\n+91 9845704455
# 16            No   3.9/5    133  +91 9972988038\r\n+91 9900121238
# 17            No   3.8/5    144    080 26711554\r\n+91 9741406338
# 18            No   3.9/5     93                    +91 8884726600
# 19            No   3.1/5     13                    +91 9880594520
# 20            No   3.0/5     62  +91 9880016665\r\n+91 8217311687
# 21            No   3.7/5    180                    +91 7406822844
# 22            No   3.6/5     28                      080 32486296
# 23            No   3.6/5     62    080 65975430\r\n+91 7337733798
# 24            No   3.7/5     31                    +91 9901481185
# 25            No   3.2/5     11                    +91 8971090261
# 26            No   3.8/5     75                    +91 9945758046
# 27            No   3.3/5      4                    +91 9008628448
# 28            No   3.3/5     23                    +91 9591111123
# 29            No   3.8/5    148    080 26600704\r\n+91 9342593424
# ...          ...     ...    ...                               ...
# 51687        Yes  4.4 /5   1980                      080 49652108
# 51688        Yes  4.0 /5   2856                      080 49652519
# 51689        Yes  4.1 /5    564    +91 9945577195\n+91 9886144774
# 51690        Yes  4.2 /5    320      +91 8296412555\n080 28413555
# 51691        Yes  4.2 /5    156    +91 9667540036\n+91 7042349751
# 51692        Yes  3.9 /5    578    +91 9845555740\n+91 9886743857
# 51693        Yes  4.1 /5    137                      080 49652780
# 51694         No  4.1 /5   2773    +91 8049626661\n+91 9886252234
# 51695        Yes  4.2 /5   1113                      080 49653340
# 51696        Yes  4.3 /5   1776    +91 8317403477\n+91 9886634664
# 51697        Yes  4.4 /5   1313        080 67266655\n080 49626655
# 51698         No  3.9 /5     74                      080 68141414
# 51699        Yes  4.1 /5   1218    +91 7676924054\n+91 9137153744
# 51700        Yes  4.1 /5   1003    +91 7338630404\n+91 8067266651
# 51701        Yes  4.1 /5    673                    +91 8929188573
# 51702         No  4.0 /5   1094                     00 9108214702
# 51703        Yes  3.9 /5    548    +91 8043691111\n+91 8028026519
# 51704        Yes  4.0 /5    189    +91 9900069474\n+91 7899644468
# 51705        Yes  3.8 /5    128    +91 7625087121\n+91 8050587483
# 51706         No  3.7 /5     27                    +91 9740571131
# 51707         No  3.9 /5     77                      080 49435000
# 51708         No  2.8 /5    161      080 39451000\n+91 8884038484
# 51709         No  3.7 /5     34    +91 9980121279\n+91 9900240646
# 51710         No     NaN      0                    +91 9148155994
# 51711         No  2.5 /5     81                      080 65951222
# 51712         No  3.6 /5     27                      080 40301477
# 51713         No     NaN      0                    +91 8197675843
# 51714         No     NaN      0                               NaN
# 51715        Yes  4.3 /5    236                      080 49652769
# 51716         No  3.4 /5     13                    +91 8071117272
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# 5                    Basavanagudi        Casual Dining
# 6                     Mysore Road        Casual Dining
# 7                    Banashankari  Casual Dining, Cafe
# 8                    Banashankari                 Cafe
# 9                    Banashankari                 Cafe
# 10                   Banashankari                 Cafe
# 11                   Banashankari                 Cafe
# 12                   Banashankari                 Cafe
# 13                   Banashankari                 Cafe
# 14                   Banashankari  Cafe, Casual Dining
# 15                   Banashankari                 Cafe
# 16                   Banashankari                 Cafe
# 17                   Banashankari                 Cafe
# 18                   Banashankari                 Cafe
# 19                   Banashankari                 Cafe
# 20                   Banashankari                 Cafe
# 21                   Banashankari                 Cafe
# 22                   Banashankari                 Cafe
# 23                   Banashankari    Quick Bites, Cafe
# 24                   Banashankari                 Cafe
# 25                   Banashankari                 Cafe
# 26                   Banashankari    Cafe, Quick Bites
# 27                   Banashankari                 Cafe
# 28                   Banashankari                 Cafe
# 29                   Basavanagudi  Casual Dining, Cafe
# ...                           ...                  ...
# 51687                  Whitefield    Microbrewery, Pub
# 51688                  Whitefield   Casual Dining, Bar
# 51689                  Whitefield   Casual Dining, Bar
# 51690                  Whitefield                  Pub
# 51691                  Whitefield   Bar, Casual Dining
# 51692                  Whitefield          Lounge, Bar
# 51693                  Whitefield                  Bar
# 51694                  Whitefield                  Pub
# 51695                  Whitefield    Pub, Microbrewery
# 51696                  Whitefield   Casual Dining, Pub
# 51697                  Whitefield   Casual Dining, Bar
# 51698                  Whitefield   Casual Dining, Bar
# 51699                  Whitefield                  Pub
# 51700                  Whitefield   Bar, Casual Dining
# 51701                  Whitefield                  Pub
# 51702                  Whitefield                  Bar
# 51703                  Whitefield   Pub, Casual Dining
# 51704                  Whitefield   Casual Dining, Pub
# 51705                  Whitefield   Bar, Casual Dining
# 51706                  Whitefield                  Pub
# 51707                  Whitefield     Fine Dining, Bar
# 51708                  Whitefield   Casual Dining, Bar
# 51709                  Whitefield   Casual Dining, Bar
# 51710                  Whitefield                  Bar
# 51711                  Whitefield   Casual Dining, Bar
# 51712                  Whitefield                  Bar
# 51713                  Whitefield                  Bar
# 51714                  Whitefield                  Bar
# 51715  ITPL Main Road, Whitefield                  Bar
# 51716  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# 5      Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
# 6                                                    NaN
# 7      Farmhouse Pizza, Chocolate Banana, Virgin Moji...
# 8      Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 9      Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
# 10     Waffles, Pasta, Crispy Chicken, Honey Chilli C...
# 11     Mocktails, Peri Fries, Lasagne, Pizza, Chicken...
# 12     Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sa...
# 13     Sandwich, Omelette, Ice Tea, Virgin Mojito, Ho...
# 14     Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 15     Garlic Bread, Burgers, Sandwiches, Pizza, Hot ...
# 16     Momos, Mushroom Bruschettas, Jalapeno Cheeseba...
# 17     Pasta, Gelato, Garlic Bread, Mojito, Nachos, P...
# 18        Cheese Maggi, Peri Peri Fries, Pasta Arrabiata
# 19                                                   NaN
# 20     Burgers, Caramel Milkshake, Iced Coffee, Iced Tea
# 21                                   Pizza, Garlic Bread
# 22                                                   NaN
# 23                                       Pasta, Iced Tea
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29     Paratha, Sandwich, Chilli Idli, Noodles, Sandw...
# ...                                                  ...
# 51687  Beer, Margarita, Long Island Iced Tea, Cocktai...
# 51688  Chicken Salad, Mocktails, Mutton Curry, Chicke...
# 51689  Mocktails, Pizza, Crispy Chicken, Beer, Nachos...
# 51690  Tempura Prawns, Cocktails, Noodles, Masala Pea...
# 51691  Deep Dish Pizza, Mocktails, Burgers, Onion Rin...
# 51692  Pasta, Fish, Beer, Chicken Wings, Mocktails, G...
# 51693                             Cocktails, Pasta, Fish
# 51694  Cocktails, Chicken Kebab, Murgh Ghee Roast, Vi...
# 51695  Beer, Chicken Tikka, Cosmopolitan, Burgers, Co...
# 51696  Beer, Cocktails, Burgers, Chicken Nachos, Mock...
# 51697  California Roll, Cocktails, Mocktails, Maki Ro...
# 51698                                          Dal Halwa
# 51699  Cocktails, Beer, Long Island Iced Tea, Pasta, ...
# 51700  Mocktails, Cocktails, Pizza, Chicken Tikka, Na...
# 51701  Cocktails, Wheat Beer, Bruschettas, Pasta, Bur...
# 51702  Cocktails, Beer, Pizza, Long Island Iced Tea, ...
# 51703  Pizza, Beer, Cocktails, Nachos, Pasta, Moo Bur...
# 51704                                        Pizza, Beer
# 51705  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51706                                                NaN
# 51707                                   Rooftop Ambience
# 51708  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51709                                                NaN
# 51710                                                NaN
# 51711                               Biryani, Andhra Meal
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                                 cuisines  \
# 0                         North Indian, Mughlai, Chinese
# 1                            Chinese, North Indian, Thai
# 2                                 Cafe, Mexican, Italian
# 3                             South Indian, North Indian
# 4                               North Indian, Rajasthani
# 5                                           North Indian
# 6            North Indian, South Indian, Andhra, Chinese
# 7                                   Pizza, Cafe, Italian
# 8                             Cafe, Italian, Continental
# 9               Cafe, Mexican, Italian, Momos, Beverages
# 10                                                  Cafe
# 11                            Cafe, Italian, Continental
# 12                   Cafe, Chinese, Continental, Italian
# 13                                     Cafe, Continental
# 14                                Cafe, Mexican, Italian
# 15                                                  Cafe
# 16          Cafe, Fast Food, Continental, Chinese, Momos
# 17                                Chinese, Cafe, Italian
# 18                               Cafe, Italian, American
# 19                   Cafe, Chinese, Continental, Italian
# 20                            Cafe, French, North Indian
# 21                     Cafe, Pizza, Fast Food, Beverages
# 22                                       Cafe, Fast Food
# 23                    Italian, Fast Food, Cafe, European
# 24                                                  Cafe
# 25                                          Cafe, Bakery
# 26                                    Cafe, South Indian
# 27                            Cafe, Fast Food, Beverages
# 28                                       Cafe, Fast Food
# 29                North Indian, Cafe, Chinese, Fast Food
# ...                                                  ...
# 51687  Continental, Mediterranean, South Indian, Nort...
# 51688             Mughlai, North Indian, Biryani, Afghan
# 51689    North Indian, Italian, Finger Food, Continental
# 51690                       Asian, Continental, European
# 51691                                  American, Italian
# 51692                               Continental, Chinese
# 51693             Continental, North Indian, Finger Food
# 51694  American, North Indian, Chinese, Finger Food, ...
# 51695                          British, Continental, BBQ
# 51696                                 European, American
# 51697  Asian, Japanese, Vietnamese, Korean, Chinese, ...
# 51698  North Indian, South Indian, Continental, Ameri...
# 51699                           Asian, American, Mexican
# 51700                 Continental, North Indian, Italian
# 51701        Finger Food, North Indian, Chinese, Italian
# 51702              Finger Food, American, Asian, Italian
# 51703  Finger Food, American, Continental, Burger, Pizza
# 51704                       North Indian, Pizza, Chinese
# 51705           North Indian, Continental, Mediterranean
# 51706                          North Indian, Continental
# 51707                                        Finger Food
# 51708                 Chinese, Continental, North Indian
# 51709                          North Indian, Continental
# 51710                                        Finger Food
# 51711        Andhra, South Indian, Chinese, North Indian
# 51712                                        Continental
# 51713                                        Finger Food
# 51714                                        Finger Food
# 51715                                        Finger Food
# 51716             Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# 5                             600
# 6                             800
# 7                             600
# 8                             700
# 9                             550
# 10                            500
# 11                            600
# 12                            500
# 13                            450
# 14                            800
# 15                            650
# 16                            800
# 17                            700
# 18                            300
# 19                            400
# 20                            400
# 21                            500
# 22                            900
# 23                            600
# 24                            300
# 25                            600
# 26                            200
# 27                            500
# 28                            550
# 29                            550
# ...                           ...
# 51687                       1,700
# 51688                       1,100
# 51689                       1,000
# 51690                       1,500
# 51691                       1,800
# 51692                       1,000
# 51693                       1,200
# 51694                       1,500
# 51695                       1,600
# 51696                       1,700
# 51697                       1,800
# 51698                       1,200
# 51699                       1,200
# 51700                       1,500
# 51701                       1,400
# 51702                       1,450
# 51703                       1,500
# 51704                       1,500
# 51705                       1,200
# 51706                       1,200
# 51707                       2,000
# 51708                       1,200
# 51709                         800
# 51710                         900
# 51711                         800
# 51712                       1,500
# 51713                         600
# 51714                       2,000
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# 5      [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...
# 6      [('Rated 5.0', 'RATED\n  Awesome food ??Great ...
# 7      [('Rated 5.0', 'RATED\n  I personally really l...
# 8      [('Rated 3.0', "RATED\n  I had been to this pl...
# 9      [('Rated 4.0', "RATED\n  Easy to locate\nVFM 3...
# 10     [('Rated 4.0', 'RATED\n  We ended up here on a...
# 11     [('Rated 1.0', "RATED\n \n\nHorrible. Not even...
# 12     [('Rated 4.0', "RATED\n  Food - 4/5\nAmbience ...
# 13     [('Rated 2.0', "RATED\n  This is a hookah cafe...
# 14     [('Rated 3.0', "RATED\n  Ambience is not that ...
# 15     [('Rated 2.0', 'RATED\n  Not so good place as ...
# 16     [('Rated 1.0', "RATED\n  This place is right o...
# 17     [('Rated 3.0', "RATED\n  New place.. though it...
# 18     [('Rated 4.0', "RATED\n  Happy to see such a c...
# 19     [('Rated 5.0', 'RATED\n  Friendly staffs , nic...
# 20     [('Rated 2.0', "RATED\n  This is a tiny cafÃ\...
# 21     [('Rated 3.0', 'RATED\n  Decided to take a bre...
# 22     [('Rated 4.0', 'RATED\n  This outlet is better...
# 23     [('Rated 4.0', "RATED\n  So, went here with fr...
# 24     [('Rated 4.0', 'RATED\n  The food was quite go...
# 25     [('Rated 1.0', "RATED\n  No ventilation. Smoke...
# 26     [('Rated 5.0', 'RATED\n  please provide some e...
# 27     [('Rated 5.0', 'RATED\n  Newly opened cafe nea...
# 28     [('Rated 1.5', 'RATED\n  This place was good t...
# 29     [('Rated 5.0', 'RATED\n  No words for the pane...
# ...                                                  ...
# 51687  [('Rated 4.0', 'RATED\n  Red Rhino is a Brewer...
# 51688  [('Rated 4.0', 'RATED\n  Was there on last Wed...
# 51689  [('Rated 3.0', "RATED\n  HQ is located at grou...
# 51690  [('Rated 3.0', 'RATED\n  Went with Team on Thu...
# 51691  [('Rated 4.0', "RATED\n  Had been here for lun...
# 51692  [('Rated 3.0', 'RATED\n  Amoeba is affordable ...
# 51693  [('Rated 4.0', 'RATED\n  Had been there on a S...
# 51694  [('Rated 2.0', 'RATED\n  Honestly speaking it ...
# 51695  [('Rated 4.0', "RATED\n  I never knew of this ...
# 51696  [('Rated 4.0', 'RATED\n  Nice place to grab a ...
# 51697  [('Rated 3.0', 'RATED\n  Wanted to try this pl...
# 51698  [('Rated 4.0', 'RATED\n  Loved the food, thoug...
# 51699  [('Rated 4.0', 'RATED\n  The first thing that ...
# 51700  [('Rated 4.0', "RATED\n  In an increasingly ov...
# 51701  [('Rated 2.0', "RATED\n  We went out to this p...
# 51702  [('Rated 4.0', 'RATED\n  A good place to dine....
# 51703  [('Rated 4.0', "RATED\n  I had :-\n\n1. Italia...
# 51704  [('Rated 3.0', 'RATED\n  Like this place for z...
# 51705  [('Rated 3.0', "RATED\n  Nice place to hangout...
# 51706  [('Rated 5.0', 'RATED\n  Excellent place had n...
# 51707  [('Rated 4.0', 'RATED\n  Went there post dinne...
# 51708  [('Rated 3.0', 'RATED\n  Place is good not tha...
# 51709  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...
# 51710  [('Rated 4.0', "RATED\n  A divine joint for Fl...
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...
# 51713                                                 []
# 51714                                                 []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...
#
#                                                menu_item listed_in(type)  \
# 0                                                     []          Buffet
# 1                                                     []          Buffet
# 2                                                     []          Buffet
# 3                                                     []          Buffet
# 4                                                     []          Buffet
# 5                                                     []          Buffet
# 6                                                     []          Buffet
# 7                                                     []           Cafes
# 8                                                     []           Cafes
# 9                                                     []           Cafes
# 10                                                    []           Cafes
# 11                                                    []           Cafes
# 12                                                    []           Cafes
# 13                                                    []           Cafes
# 14                                                    []           Cafes
# 15                                                    []           Cafes
# 16                                                    []           Cafes
# 17                                                    []           Cafes
# 18                                                    []           Cafes
# 19                                                    []           Cafes
# 20                                                    []           Cafes
# 21                                                    []           Cafes
# 22                                                    []           Cafes
# 23                                                    []           Cafes
# 24                                                    []           Cafes
# 25                                                    []           Cafes
# 26                                                    []           Cafes
# 27                                                    []           Cafes
# 28                                                    []           Cafes
# 29                                                    []           Cafes
# ...                                                  ...             ...
# 51687  ['Hangover', 'Smoking Hot Red Rhino Chilli Chi...   Pubs and bars
# 51688  ['Dal Tadka', 'Dal Makhani', 'Paneer Tikka Mas...   Pubs and bars
# 51689                                                 []   Pubs and bars
# 51690                                                 []   Pubs and bars
# 51691                                                 []   Pubs and bars
# 51692                                                 []   Pubs and bars
# 51693  ['Chicken Manchow Soup', 'Chicken Lollipop', '...   Pubs and bars
# 51694  ['Chilli Paneer Black Pepper China Box', 'Chil...   Pubs and bars
# 51695                                                 []   Pubs and bars
# 51696                                                 []   Pubs and bars
# 51697                                                 []   Pubs and bars
# 51698                                                 []   Pubs and bars
# 51699                                                 []   Pubs and bars
# 51700                                                 []   Pubs and bars
# 51701                                                 []   Pubs and bars
# 51702                                                 []   Pubs and bars
# 51703                                                 []   Pubs and bars
# 51704                                                 []   Pubs and bars
# 51705                                                 []   Pubs and bars
# 51706                                                 []   Pubs and bars
# 51707                                                 []   Pubs and bars
# 51708                                                 []   Pubs and bars
# 51709                                                 []   Pubs and bars
# 51710                                                 []   Pubs and bars
# 51711                                                 []   Pubs and bars
# 51712                                                 []   Pubs and bars
# 51713                                                 []   Pubs and bars
# 51714                                                 []   Pubs and bars
# 51715                                                 []   Pubs and bars
# 51716                                                 []   Pubs and bars
#
#       listed_in(city)
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
# 5        Banashankari
# 6        Banashankari
# 7        Banashankari
# 8        Banashankari
# 9        Banashankari
# 10       Banashankari
# 11       Banashankari
# 12       Banashankari
# 13       Banashankari
# 14       Banashankari
# 15       Banashankari
# 16       Banashankari
# 17       Banashankari
# 18       Banashankari
# 19       Banashankari
# 20       Banashankari
# 21       Banashankari
# 22       Banashankari
# 23       Banashankari
# 24       Banashankari
# 25       Banashankari
# 26       Banashankari
# 27       Banashankari
# 28       Banashankari
# 29       Banashankari
# ...               ...
# 51687      Whitefield
# 51688      Whitefield
# 51689      Whitefield
# 51690      Whitefield
# 51691      Whitefield
# 51692      Whitefield
# 51693      Whitefield
# 51694      Whitefield
# 51695      Whitefield
# 51696      Whitefield
# 51697      Whitefield
# 51698      Whitefield
# 51699      Whitefield
# 51700      Whitefield
# 51701      Whitefield
# 51702      Whitefield
# 51703      Whitefield
# 51704      Whitefield
# 51705      Whitefield
# 51706      Whitefield
# 51707      Whitefield
# 51708      Whitefield
# 51709      Whitefield
# 51710      Whitefield
# 51711      Whitefield
# 51712      Whitefield
# 51713      Whitefield
# 51714      Whitefield
# 51715      Whitefield
# 51716      Whitefield
#
# [51717 rows x 17 columns]

# %% [markdown]
# __2. Basic Data Understanding__
#
# Let’s start with basic data understanding by checking the data types of the columns in which we are interested to work with.

# %%
zom.shape
# Out:
# (51717, 17)

# %%
#get the datatypes of the columns
zom.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
#count of data types
zom.dtypes.value_counts()
# Out:
# object    16
# int64      1
# dtype: int64

# %% [markdown]
# __Q. WHat do you think about the variable types? Are they correctly presented?
# _Ans:___ No, the cost variable should be integer type, but it is given to as a string type(object). Also the way in which rating is provided will hinder the comparison of ratings.

# %%
zom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
# url                            51717 non-null object
# address                        51717 non-null object
# name                           51717 non-null object
# online_order                   51717 non-null object
# book_table                     51717 non-null object
# rate                           43942 non-null object
# votes                          51717 non-null int64
# phone                          50509 non-null object
# location                       51696 non-null object
# rest_type                      51490 non-null object
# dish_liked                     23639 non-null object
# cuisines                       51672 non-null object
# approx_cost(for two people)    51371 non-null object
# reviews_list                   51717 non-null object
# menu_item                      51717 non-null object
# listed_in(type)                51717 non-null object
# listed_in(city)                51717 non-null object
# dtypes: int64(1), object(16)
# memory usage: 6.7+ MB

# %% [markdown]
# __Q. Which variables should be changed to integer if we want to perform any business analysis on them. Look at the original csv/excel data and think analytically.
# _Ans:__ The approx_cost(for two people) should be changed to integer for comparisons. Also the rating should converted to float.

# %% [markdown]
# You can try to get the list of all the columns present in the dataset:

# %%
zom.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %% [markdown]
# Initially consider the `votes` column and find its basic statistical measures

# %%
zom.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %% [markdown]
# __3. Data Cleaning & Data Manipulation__
#
# In this section, we will discuss some of the basic data cleaning techniques like checking for duplicate values & handling missing values. Apart from data cleaning, we will also discuss some of the manipulation techniques like changing the data type of the variables, dropping unwanted variables and renaming the columns for convenience.

# %%
#check for any duplicate values
zom.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values present in this dataset.
# Now we will check for missing values

# %%
#check for missing values
pd.DataFrame(zom.isna().sum(),columns=["Missing"])
# Out:
#                              Missing
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0

# %% [markdown]
# __Q. What is your observation from the missing data findings?__
# __Ans:__ There are many missing values, especially in the dish_liked columns.

# %% [markdown]
# - To simplify the analysis, we will drop some of the columns that are not very useful like `url, address and phone`.

# %%
# drop url, address and phone column and update the data at the same time
zom.drop(labels=["url","address","phone"],axis=1,inplace=True)

# %% [markdown]
# Renaming few columns for convenience

# %%
#Rename as per below name
#"approx_cost(for two people)" to "cost_two"
#"listed_in(type)" to "service_type"
#"listed_in(city)" to "serve_to"
zom.rename({"approx_cost(for two people)":"cost_two","listed_in(type)":"service_type","listed_in(city)" : "serve_to"},axis=1,inplace=True)

# %%
#Check again the data 
zom
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# 5                                        Timepass Dinner          Yes
# 6        Rosewood International Hotel - Bar & Restaurant           No
# 7                                                 Onesta          Yes
# 8                                         Penthouse Cafe          Yes
# 9                                              Smacznego          Yes
# 10     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          Yes
# 11                                          Cafe Shuffle          Yes
# 12                                      The Coffee Shack          Yes
# 13                                            Caf-Eleven           No
# 14                                       San Churro Cafe          Yes
# 15                                         Cafe Vivacity          Yes
# 16                                          Catch-up-ino          Yes
# 17                                      Kirthi's Biryani          Yes
# 18                                              T3H Cafe           No
# 19                         360 Atoms Restaurant And Cafe          Yes
# 20                                      The Vintage Cafe          Yes
# 21                                          Woodee Pizza          Yes
# 22                                       Cafe Coffee Day           No
# 23                                          My Tea House          Yes
# 24                                         Hide Out Cafe           No
# 25                                             CAFE NOVA           No
# 26                                          Coffee Tindi          Yes
# 27                                        Sea Green Cafe           No
# 28                                                 Cuppa           No
# 29                                      Srinathji's Cafe           No
# ...                                                  ...          ...
# 51687                                          Red Rhino          Yes
# 51688                                          Ji Hazoor          Yes
# 51689                                                 HQ           No
# 51690                                     Biere Societee           No
# 51691                            Uno Chicago Bar & Grill           No
# 51692                                  Amoeba Sports Bar          Yes
# 51693                                   One For The Road          Yes
# 51694                                  Whitefield Social          Yes
# 51695             The Whitefield Arms Pub & Microbrewery          Yes
# 51696                                    The Irish House           No
# 51697                           Shizusan Shophouse & Bar          Yes
# 51698         Kava Kitchen & Bar - Fairfield by Marriott           No
# 51699                                 Harry's Bar + Cafe          Yes
# 51700                                            BAR BAR           No
# 51701                                      The Beer Cafe          Yes
# 51702                                  Pablo's Gastrobar           No
# 51703                               Oliver's Pub & Diner          Yes
# 51704                                            Smaaash           No
# 51705                                 Izakaya Gastro Pub          Yes
# 51706                                           Red Glow           No
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 51708                             Keys Cafe - Keys Hotel           No
# 51709                         The Farm House Bar n Grill           No
# 51710                                       Topsy Turvey           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# 5             No   3.8/5    286                Basavanagudi
# 6             No   3.6/5      8                 Mysore Road
# 7            Yes   4.6/5   2556                Banashankari
# 8             No   4.0/5    324                Banashankari
# 9             No   4.2/5    504                Banashankari
# 10            No   4.1/5    402                Banashankari
# 11           Yes   4.2/5    150                Banashankari
# 12           Yes   4.2/5    164                Banashankari
# 13            No   4.0/5    424                Banashankari
# 14            No   3.8/5    918                Banashankari
# 15            No   3.8/5     90                Banashankari
# 16            No   3.9/5    133                Banashankari
# 17            No   3.8/5    144                Banashankari
# 18            No   3.9/5     93                Banashankari
# 19            No   3.1/5     13                Banashankari
# 20            No   3.0/5     62                Banashankari
# 21            No   3.7/5    180                Banashankari
# 22            No   3.6/5     28                Banashankari
# 23            No   3.6/5     62                Banashankari
# 24            No   3.7/5     31                Banashankari
# 25            No   3.2/5     11                Banashankari
# 26            No   3.8/5     75                Banashankari
# 27            No   3.3/5      4                Banashankari
# 28            No   3.3/5     23                Banashankari
# 29            No   3.8/5    148                Basavanagudi
# ...          ...     ...    ...                         ...
# 51687        Yes  4.4 /5   1980                  Whitefield
# 51688        Yes  4.0 /5   2856                  Whitefield
# 51689        Yes  4.1 /5    564                  Whitefield
# 51690        Yes  4.2 /5    320                  Whitefield
# 51691        Yes  4.2 /5    156                  Whitefield
# 51692        Yes  3.9 /5    578                  Whitefield
# 51693        Yes  4.1 /5    137                  Whitefield
# 51694         No  4.1 /5   2773                  Whitefield
# 51695        Yes  4.2 /5   1113                  Whitefield
# 51696        Yes  4.3 /5   1776                  Whitefield
# 51697        Yes  4.4 /5   1313                  Whitefield
# 51698         No  3.9 /5     74                  Whitefield
# 51699        Yes  4.1 /5   1218                  Whitefield
# 51700        Yes  4.1 /5   1003                  Whitefield
# 51701        Yes  4.1 /5    673                  Whitefield
# 51702         No  4.0 /5   1094                  Whitefield
# 51703        Yes  3.9 /5    548                  Whitefield
# 51704        Yes  4.0 /5    189                  Whitefield
# 51705        Yes  3.8 /5    128                  Whitefield
# 51706         No  3.7 /5     27                  Whitefield
# 51707         No  3.9 /5     77                  Whitefield
# 51708         No  2.8 /5    161                  Whitefield
# 51709         No  3.7 /5     34                  Whitefield
# 51710         No     NaN      0                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                         dish_liked  \
# 0            Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1            Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3              Quick Bites                                        Masala Dosa
# 4            Casual Dining                                Panipuri, Gol Gappe
# 5            Casual Dining  Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
# 6            Casual Dining                                                NaN
# 7      Casual Dining, Cafe  Farmhouse Pizza, Chocolate Banana, Virgin Moji...
# 8                     Cafe  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 9                     Cafe  Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
# 10                    Cafe  Waffles, Pasta, Crispy Chicken, Honey Chilli C...
# 11                    Cafe  Mocktails, Peri Fries, Lasagne, Pizza, Chicken...
# 12                    Cafe  Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sa...
# 13                    Cafe  Sandwich, Omelette, Ice Tea, Virgin Mojito, Ho...
# 14     Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 15                    Cafe  Garlic Bread, Burgers, Sandwiches, Pizza, Hot ...
# 16                    Cafe  Momos, Mushroom Bruschettas, Jalapeno Cheeseba...
# 17                    Cafe  Pasta, Gelato, Garlic Bread, Mojito, Nachos, P...
# 18                    Cafe     Cheese Maggi, Peri Peri Fries, Pasta Arrabiata
# 19                    Cafe                                                NaN
# 20                    Cafe  Burgers, Caramel Milkshake, Iced Coffee, Iced Tea
# 21                    Cafe                                Pizza, Garlic Bread
# 22                    Cafe                                                NaN
# 23       Quick Bites, Cafe                                    Pasta, Iced Tea
# 24                    Cafe                                                NaN
# 25                    Cafe                                                NaN
# 26       Cafe, Quick Bites                                                NaN
# 27                    Cafe                                                NaN
# 28                    Cafe                                                NaN
# 29     Casual Dining, Cafe  Paratha, Sandwich, Chilli Idli, Noodles, Sandw...
# ...                    ...                                                ...
# 51687    Microbrewery, Pub  Beer, Margarita, Long Island Iced Tea, Cocktai...
# 51688   Casual Dining, Bar  Chicken Salad, Mocktails, Mutton Curry, Chicke...
# 51689   Casual Dining, Bar  Mocktails, Pizza, Crispy Chicken, Beer, Nachos...
# 51690                  Pub  Tempura Prawns, Cocktails, Noodles, Masala Pea...
# 51691   Bar, Casual Dining  Deep Dish Pizza, Mocktails, Burgers, Onion Rin...
# 51692          Lounge, Bar  Pasta, Fish, Beer, Chicken Wings, Mocktails, G...
# 51693                  Bar                             Cocktails, Pasta, Fish
# 51694                  Pub  Cocktails, Chicken Kebab, Murgh Ghee Roast, Vi...
# 51695    Pub, Microbrewery  Beer, Chicken Tikka, Cosmopolitan, Burgers, Co...
# 51696   Casual Dining, Pub  Beer, Cocktails, Burgers, Chicken Nachos, Mock...
# 51697   Casual Dining, Bar  California Roll, Cocktails, Mocktails, Maki Ro...
# 51698   Casual Dining, Bar                                          Dal Halwa
# 51699                  Pub  Cocktails, Beer, Long Island Iced Tea, Pasta, ...
# 51700   Bar, Casual Dining  Mocktails, Cocktails, Pizza, Chicken Tikka, Na...
# 51701                  Pub  Cocktails, Wheat Beer, Bruschettas, Pasta, Bur...
# 51702                  Bar  Cocktails, Beer, Pizza, Long Island Iced Tea, ...
# 51703   Pub, Casual Dining  Pizza, Beer, Cocktails, Nachos, Pasta, Moo Bur...
# 51704   Casual Dining, Pub                                        Pizza, Beer
# 51705   Bar, Casual Dining  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51706                  Pub                                                NaN
# 51707     Fine Dining, Bar                                   Rooftop Ambience
# 51708   Casual Dining, Bar  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51709   Casual Dining, Bar                                                NaN
# 51710                  Bar                                                NaN
# 51711   Casual Dining, Bar                               Biryani, Andhra Meal
# 51712                  Bar                                                NaN
# 51713                  Bar                                                NaN
# 51714                  Bar                                                NaN
# 51715                  Bar                       Cocktails, Pizza, Buttermilk
# 51716   Bar, Casual Dining                                                NaN
#
#                                                 cuisines cost_two  \
# 0                         North Indian, Mughlai, Chinese      800
# 1                            Chinese, North Indian, Thai      800
# 2                                 Cafe, Mexican, Italian      800
# 3                             South Indian, North Indian      300
# 4                               North Indian, Rajasthani      600
# 5                                           North Indian      600
# 6            North Indian, South Indian, Andhra, Chinese      800
# 7                                   Pizza, Cafe, Italian      600
# 8                             Cafe, Italian, Continental      700
# 9               Cafe, Mexican, Italian, Momos, Beverages      550
# 10                                                  Cafe      500
# 11                            Cafe, Italian, Continental      600
# 12                   Cafe, Chinese, Continental, Italian      500
# 13                                     Cafe, Continental      450
# 14                                Cafe, Mexican, Italian      800
# 15                                                  Cafe      650
# 16          Cafe, Fast Food, Continental, Chinese, Momos      800
# 17                                Chinese, Cafe, Italian      700
# 18                               Cafe, Italian, American      300
# 19                   Cafe, Chinese, Continental, Italian      400
# 20                            Cafe, French, North Indian      400
# 21                     Cafe, Pizza, Fast Food, Beverages      500
# 22                                       Cafe, Fast Food      900
# 23                    Italian, Fast Food, Cafe, European      600
# 24                                                  Cafe      300
# 25                                          Cafe, Bakery      600
# 26                                    Cafe, South Indian      200
# 27                            Cafe, Fast Food, Beverages      500
# 28                                       Cafe, Fast Food      550
# 29                North Indian, Cafe, Chinese, Fast Food      550
# ...                                                  ...      ...
# 51687  Continental, Mediterranean, South Indian, Nort...    1,700
# 51688             Mughlai, North Indian, Biryani, Afghan    1,100
# 51689    North Indian, Italian, Finger Food, Continental    1,000
# 51690                       Asian, Continental, European    1,500
# 51691                                  American, Italian    1,800
# 51692                               Continental, Chinese    1,000
# 51693             Continental, North Indian, Finger Food    1,200
# 51694  American, North Indian, Chinese, Finger Food, ...    1,500
# 51695                          British, Continental, BBQ    1,600
# 51696                                 European, American    1,700
# 51697  Asian, Japanese, Vietnamese, Korean, Chinese, ...    1,800
# 51698  North Indian, South Indian, Continental, Ameri...    1,200
# 51699                           Asian, American, Mexican    1,200
# 51700                 Continental, North Indian, Italian    1,500
# 51701        Finger Food, North Indian, Chinese, Italian    1,400
# 51702              Finger Food, American, Asian, Italian    1,450
# 51703  Finger Food, American, Continental, Burger, Pizza    1,500
# 51704                       North Indian, Pizza, Chinese    1,500
# 51705           North Indian, Continental, Mediterranean    1,200
# 51706                          North Indian, Continental    1,200
# 51707                                        Finger Food    2,000
# 51708                 Chinese, Continental, North Indian    1,200
# 51709                          North Indian, Continental      800
# 51710                                        Finger Food      900
# 51711        Andhra, South Indian, Chinese, North Indian      800
# 51712                                        Continental    1,500
# 51713                                        Finger Food      600
# 51714                                        Finger Food    2,000
# 51715                                        Finger Food    2,500
# 51716             Finger Food, North Indian, Continental    1,500
#
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# 5      [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...
# 6      [('Rated 5.0', 'RATED\n  Awesome food ??Great ...
# 7      [('Rated 5.0', 'RATED\n  I personally really l...
# 8      [('Rated 3.0', "RATED\n  I had been to this pl...
# 9      [('Rated 4.0', "RATED\n  Easy to locate\nVFM 3...
# 10     [('Rated 4.0', 'RATED\n  We ended up here on a...
# 11     [('Rated 1.0', "RATED\n \n\nHorrible. Not even...
# 12     [('Rated 4.0', "RATED\n  Food - 4/5\nAmbience ...
# 13     [('Rated 2.0', "RATED\n  This is a hookah cafe...
# 14     [('Rated 3.0', "RATED\n  Ambience is not that ...
# 15     [('Rated 2.0', 'RATED\n  Not so good place as ...
# 16     [('Rated 1.0', "RATED\n  This place is right o...
# 17     [('Rated 3.0', "RATED\n  New place.. though it...
# 18     [('Rated 4.0', "RATED\n  Happy to see such a c...
# 19     [('Rated 5.0', 'RATED\n  Friendly staffs , nic...
# 20     [('Rated 2.0', "RATED\n  This is a tiny cafÃ\...
# 21     [('Rated 3.0', 'RATED\n  Decided to take a bre...
# 22     [('Rated 4.0', 'RATED\n  This outlet is better...
# 23     [('Rated 4.0', "RATED\n  So, went here with fr...
# 24     [('Rated 4.0', 'RATED\n  The food was quite go...
# 25     [('Rated 1.0', "RATED\n  No ventilation. Smoke...
# 26     [('Rated 5.0', 'RATED\n  please provide some e...
# 27     [('Rated 5.0', 'RATED\n  Newly opened cafe nea...
# 28     [('Rated 1.5', 'RATED\n  This place was good t...
# 29     [('Rated 5.0', 'RATED\n  No words for the pane...
# ...                                                  ...
# 51687  [('Rated 4.0', 'RATED\n  Red Rhino is a Brewer...
# 51688  [('Rated 4.0', 'RATED\n  Was there on last Wed...
# 51689  [('Rated 3.0', "RATED\n  HQ is located at grou...
# 51690  [('Rated 3.0', 'RATED\n  Went with Team on Thu...
# 51691  [('Rated 4.0', "RATED\n  Had been here for lun...
# 51692  [('Rated 3.0', 'RATED\n  Amoeba is affordable ...
# 51693  [('Rated 4.0', 'RATED\n  Had been there on a S...
# 51694  [('Rated 2.0', 'RATED\n  Honestly speaking it ...
# 51695  [('Rated 4.0', "RATED\n  I never knew of this ...
# 51696  [('Rated 4.0', 'RATED\n  Nice place to grab a ...
# 51697  [('Rated 3.0', 'RATED\n  Wanted to try this pl...
# 51698  [('Rated 4.0', 'RATED\n  Loved the food, thoug...
# 51699  [('Rated 4.0', 'RATED\n  The first thing that ...
# 51700  [('Rated 4.0', "RATED\n  In an increasingly ov...
# 51701  [('Rated 2.0', "RATED\n  We went out to this p...
# 51702  [('Rated 4.0', 'RATED\n  A good place to dine....
# 51703  [('Rated 4.0', "RATED\n  I had :-\n\n1. Italia...
# 51704  [('Rated 3.0', 'RATED\n  Like this place for z...
# 51705  [('Rated 3.0', "RATED\n  Nice place to hangout...
# 51706  [('Rated 5.0', 'RATED\n  Excellent place had n...
# 51707  [('Rated 4.0', 'RATED\n  Went there post dinne...
# 51708  [('Rated 3.0', 'RATED\n  Place is good not tha...
# 51709  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...
# 51710  [('Rated 4.0', "RATED\n  A divine joint for Fl...
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...
# 51713                                                 []
# 51714                                                 []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...
#
#                                                menu_item   service_type  \
# 0                                                     []         Buffet
# 1                                                     []         Buffet
# 2                                                     []         Buffet
# 3                                                     []         Buffet
# 4                                                     []         Buffet
# 5                                                     []         Buffet
# 6                                                     []         Buffet
# 7                                                     []          Cafes
# 8                                                     []          Cafes
# 9                                                     []          Cafes
# 10                                                    []          Cafes
# 11                                                    []          Cafes
# 12                                                    []          Cafes
# 13                                                    []          Cafes
# 14                                                    []          Cafes
# 15                                                    []          Cafes
# 16                                                    []          Cafes
# 17                                                    []          Cafes
# 18                                                    []          Cafes
# 19                                                    []          Cafes
# 20                                                    []          Cafes
# 21                                                    []          Cafes
# 22                                                    []          Cafes
# 23                                                    []          Cafes
# 24                                                    []          Cafes
# 25                                                    []          Cafes
# 26                                                    []          Cafes
# 27                                                    []          Cafes
# 28                                                    []          Cafes
# 29                                                    []          Cafes
# ...                                                  ...            ...
# 51687  ['Hangover', 'Smoking Hot Red Rhino Chilli Chi...  Pubs and bars
# 51688  ['Dal Tadka', 'Dal Makhani', 'Paneer Tikka Mas...  Pubs and bars
# 51689                                                 []  Pubs and bars
# 51690                                                 []  Pubs and bars
# 51691                                                 []  Pubs and bars
# 51692                                                 []  Pubs and bars
# 51693  ['Chicken Manchow Soup', 'Chicken Lollipop', '...  Pubs and bars
# 51694  ['Chilli Paneer Black Pepper China Box', 'Chil...  Pubs and bars
# 51695                                                 []  Pubs and bars
# 51696                                                 []  Pubs and bars
# 51697                                                 []  Pubs and bars
# 51698                                                 []  Pubs and bars
# 51699                                                 []  Pubs and bars
# 51700                                                 []  Pubs and bars
# 51701                                                 []  Pubs and bars
# 51702                                                 []  Pubs and bars
# 51703                                                 []  Pubs and bars
# 51704                                                 []  Pubs and bars
# 51705                                                 []  Pubs and bars
# 51706                                                 []  Pubs and bars
# 51707                                                 []  Pubs and bars
# 51708                                                 []  Pubs and bars
# 51709                                                 []  Pubs and bars
# 51710                                                 []  Pubs and bars
# 51711                                                 []  Pubs and bars
# 51712                                                 []  Pubs and bars
# 51713                                                 []  Pubs and bars
# 51714                                                 []  Pubs and bars
# 51715                                                 []  Pubs and bars
# 51716                                                 []  Pubs and bars
#
#            serve_to
# 0      Banashankari
# 1      Banashankari
# 2      Banashankari
# 3      Banashankari
# 4      Banashankari
# 5      Banashankari
# 6      Banashankari
# 7      Banashankari
# 8      Banashankari
# 9      Banashankari
# 10     Banashankari
# 11     Banashankari
# 12     Banashankari
# 13     Banashankari
# 14     Banashankari
# 15     Banashankari
# 16     Banashankari
# 17     Banashankari
# 18     Banashankari
# 19     Banashankari
# 20     Banashankari
# 21     Banashankari
# 22     Banashankari
# 23     Banashankari
# 24     Banashankari
# 25     Banashankari
# 26     Banashankari
# 27     Banashankari
# 28     Banashankari
# 29     Banashankari
# ...             ...
# 51687    Whitefield
# 51688    Whitefield
# 51689    Whitefield
# 51690    Whitefield
# 51691    Whitefield
# 51692    Whitefield
# 51693    Whitefield
# 51694    Whitefield
# 51695    Whitefield
# 51696    Whitefield
# 51697    Whitefield
# 51698    Whitefield
# 51699    Whitefield
# 51700    Whitefield
# 51701    Whitefield
# 51702    Whitefield
# 51703    Whitefield
# 51704    Whitefield
# 51705    Whitefield
# 51706    Whitefield
# 51707    Whitefield
# 51708    Whitefield
# 51709    Whitefield
# 51710    Whitefield
# 51711    Whitefield
# 51712    Whitefield
# 51713    Whitefield
# 51714    Whitefield
# 51715    Whitefield
# 51716    Whitefield
#
# [51717 rows x 14 columns]

# %% [markdown]
# `rate` is read as object, but for analysis we need that to be present in numerical format.

# %%
#Manipulating the 'rate' column - Find its distinct/unique values
zom["rate"].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
#removing the "/5" in the rate column. You can take help of lamda function statement here, use replace() and strip()
zom["rate"]=zom["rate"].apply(lambda x: str(x).replace("/5"," ").strip() )

# %%
#rate column contains 'NEW' and '-' replacing those with nan and drop those fields without any rating
# Replace "NEW" & "-" to np.nan
zom["rate"]=zom["rate"].replace(["NEW",'-','nan'],np.nan)

# %%
zom["rate"].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', nan, '2.9', '3.5', '2.6',
#        '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3', '4.8',
#        '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
#dropping the observations where rate and cost_two is null
zom.dropna(subset=["rate","cost_two"],inplace=True)

# %%
zom["rate"].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '2.9', '3.5', '2.6',
#        '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2', '2.3', '4.8',
#        '4.9', '2.1', '2.0', '1.8'], dtype=object)

# %%
#Converting Rate Column datetype to float, use .astype() method
zom["rate"]=zom["rate"].astype(float)

# %%
zom["rate"].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
#online_order and book_table are given as 'Yes' and 'No'. Converting these two True and False for better manipulation.
#use .replace() method, and do not forget to update the data at the same time
zom.replace(to_replace={"online_order":{"Yes":True,"No":False},"book_table":{"Yes":True,"No":False} },inplace=True)

# %%
zom
# Out:
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# 5                                        Timepass Dinner          True
# 6        Rosewood International Hotel - Bar & Restaurant         False
# 7                                                 Onesta          True
# 8                                         Penthouse Cafe          True
# 9                                              Smacznego          True
# 10     CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The A...          True
# 11                                          Cafe Shuffle          True
# 12                                      The Coffee Shack          True
# 13                                            Caf-Eleven         False
# 14                                       San Churro Cafe          True
# 15                                         Cafe Vivacity          True
# 16                                          Catch-up-ino          True
# 17                                      Kirthi's Biryani          True
# 18                                              T3H Cafe         False
# 19                         360 Atoms Restaurant And Cafe          True
# 20                                      The Vintage Cafe          True
# 21                                          Woodee Pizza          True
# 22                                       Cafe Coffee Day         False
# 23                                          My Tea House          True
# 24                                         Hide Out Cafe         False
# 25                                             CAFE NOVA         False
# 26                                          Coffee Tindi          True
# 27                                        Sea Green Cafe         False
# 28                                                 Cuppa         False
# 29                                      Srinathji's Cafe         False
# ...                                                  ...           ...
# 51684                                     The Biere Club         False
# 51685                                         Biergarten         False
# 51686                               Windmills Craftworks         False
# 51687                                          Red Rhino          True
# 51688                                          Ji Hazoor          True
# 51689                                                 HQ         False
# 51690                                     Biere Societee         False
# 51691                            Uno Chicago Bar & Grill         False
# 51692                                  Amoeba Sports Bar          True
# 51693                                   One For The Road          True
# 51694                                  Whitefield Social          True
# 51695             The Whitefield Arms Pub & Microbrewery          True
# 51696                                    The Irish House         False
# 51697                           Shizusan Shophouse & Bar          True
# 51698         Kava Kitchen & Bar - Fairfield by Marriott         False
# 51699                                 Harry's Bar + Cafe          True
# 51700                                            BAR BAR         False
# 51701                                      The Beer Cafe          True
# 51702                                  Pablo's Gastrobar         False
# 51703                               Oliver's Pub & Diner          True
# 51704                                            Smaaash         False
# 51705                                 Izakaya Gastro Pub          True
# 51706                                           Red Glow         False
# 51707        M Bar - Bengaluru Marriott Hotel Whitefield         False
# 51708                             Keys Cafe - Keys Hotel         False
# 51709                         The Farm House Bar n Grill         False
# 51711                                            Bhagini         False
# 51712  Best Brews - Four Points by Sheraton Bengaluru...         False
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 51716                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# 5           False   3.8    286                Basavanagudi
# 6           False   3.6      8                 Mysore Road
# 7            True   4.6   2556                Banashankari
# 8           False   4.0    324                Banashankari
# 9           False   4.2    504                Banashankari
# 10          False   4.1    402                Banashankari
# 11           True   4.2    150                Banashankari
# 12           True   4.2    164                Banashankari
# 13          False   4.0    424                Banashankari
# 14          False   3.8    918                Banashankari
# 15          False   3.8     90                Banashankari
# 16          False   3.9    133                Banashankari
# 17          False   3.8    144                Banashankari
# 18          False   3.9     93                Banashankari
# 19          False   3.1     13                Banashankari
# 20          False   3.0     62                Banashankari
# 21          False   3.7    180                Banashankari
# 22          False   3.6     28                Banashankari
# 23          False   3.6     62                Banashankari
# 24          False   3.7     31                Banashankari
# 25          False   3.2     11                Banashankari
# 26          False   3.8     75                Banashankari
# 27          False   3.3      4                Banashankari
# 28          False   3.3     23                Banashankari
# 29          False   3.8    148                Basavanagudi
# ...           ...   ...    ...                         ...
# 51684        True   4.3   2283                  Whitefield
# 51685        True   4.7   7064                  Whitefield
# 51686       False   4.6   5954                  Whitefield
# 51687        True   4.4   1980                  Whitefield
# 51688        True   4.0   2856                  Whitefield
# 51689        True   4.1    564                  Whitefield
# 51690        True   4.2    320                  Whitefield
# 51691        True   4.2    156                  Whitefield
# 51692        True   3.9    578                  Whitefield
# 51693        True   4.1    137                  Whitefield
# 51694       False   4.1   2773                  Whitefield
# 51695        True   4.2   1113                  Whitefield
# 51696        True   4.3   1776                  Whitefield
# 51697        True   4.4   1313                  Whitefield
# 51698       False   3.9     74                  Whitefield
# 51699        True   4.1   1218                  Whitefield
# 51700        True   4.1   1003                  Whitefield
# 51701        True   4.1    673                  Whitefield
# 51702       False   4.0   1094                  Whitefield
# 51703        True   3.9    548                  Whitefield
# 51704        True   4.0    189                  Whitefield
# 51705        True   3.8    128                  Whitefield
# 51706       False   3.7     27                  Whitefield
# 51707       False   3.9     77                  Whitefield
# 51708       False   2.8    161                  Whitefield
# 51709       False   3.7     34                  Whitefield
# 51711       False   2.5     81                  Whitefield
# 51712       False   3.6     27                  Whitefield
# 51715        True   4.3    236  ITPL Main Road, Whitefield
# 51716       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                         dish_liked  \
# 0            Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1            Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3              Quick Bites                                        Masala Dosa
# 4            Casual Dining                                Panipuri, Gol Gappe
# 5            Casual Dining  Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...
# 6            Casual Dining                                                NaN
# 7      Casual Dining, Cafe  Farmhouse Pizza, Chocolate Banana, Virgin Moji...
# 8                     Cafe  Pizza, Mocktails, Coffee, Nachos, Salad, Pasta...
# 9                     Cafe  Waffles, Pasta, Coleslaw Sandwich, Choco Waffl...
# 10                    Cafe  Waffles, Pasta, Crispy Chicken, Honey Chilli C...
# 11                    Cafe  Mocktails, Peri Fries, Lasagne, Pizza, Chicken...
# 12                    Cafe  Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sa...
# 13                    Cafe  Sandwich, Omelette, Ice Tea, Virgin Mojito, Ho...
# 14     Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 15                    Cafe  Garlic Bread, Burgers, Sandwiches, Pizza, Hot ...
# 16                    Cafe  Momos, Mushroom Bruschettas, Jalapeno Cheeseba...
# 17                    Cafe  Pasta, Gelato, Garlic Bread, Mojito, Nachos, P...
# 18                    Cafe     Cheese Maggi, Peri Peri Fries, Pasta Arrabiata
# 19                    Cafe                                                NaN
# 20                    Cafe  Burgers, Caramel Milkshake, Iced Coffee, Iced Tea
# 21                    Cafe                                Pizza, Garlic Bread
# 22                    Cafe                                                NaN
# 23       Quick Bites, Cafe                                    Pasta, Iced Tea
# 24                    Cafe                                                NaN
# 25                    Cafe                                                NaN
# 26       Cafe, Quick Bites                                                NaN
# 27                    Cafe                                                NaN
# 28                    Cafe                                                NaN
# 29     Casual Dining, Cafe  Paratha, Sandwich, Chilli Idli, Noodles, Sandw...
# ...                    ...                                                ...
# 51684    Pub, Microbrewery  Wheat Beer, Beef Burger, Pizza, Craft Beer, Po...
# 51685    Microbrewery, Pub  Wheat Beer, Risotto, Craft Beer, Caesar Salad,...
# 51686    Microbrewery, Pub  Keema Pav, Cocktails, Craft Beer, Pork Chops, ...
# 51687    Microbrewery, Pub  Beer, Margarita, Long Island Iced Tea, Cocktai...
# 51688   Casual Dining, Bar  Chicken Salad, Mocktails, Mutton Curry, Chicke...
# 51689   Casual Dining, Bar  Mocktails, Pizza, Crispy Chicken, Beer, Nachos...
# 51690                  Pub  Tempura Prawns, Cocktails, Noodles, Masala Pea...
# 51691   Bar, Casual Dining  Deep Dish Pizza, Mocktails, Burgers, Onion Rin...
# 51692          Lounge, Bar  Pasta, Fish, Beer, Chicken Wings, Mocktails, G...
# 51693                  Bar                             Cocktails, Pasta, Fish
# 51694                  Pub  Cocktails, Chicken Kebab, Murgh Ghee Roast, Vi...
# 51695    Pub, Microbrewery  Beer, Chicken Tikka, Cosmopolitan, Burgers, Co...
# 51696   Casual Dining, Pub  Beer, Cocktails, Burgers, Chicken Nachos, Mock...
# 51697   Casual Dining, Bar  California Roll, Cocktails, Mocktails, Maki Ro...
# 51698   Casual Dining, Bar                                          Dal Halwa
# 51699                  Pub  Cocktails, Beer, Long Island Iced Tea, Pasta, ...
# 51700   Bar, Casual Dining  Mocktails, Cocktails, Pizza, Chicken Tikka, Na...
# 51701                  Pub  Cocktails, Wheat Beer, Bruschettas, Pasta, Bur...
# 51702                  Bar  Cocktails, Beer, Pizza, Long Island Iced Tea, ...
# 51703   Pub, Casual Dining  Pizza, Beer, Cocktails, Nachos, Pasta, Moo Bur...
# 51704   Casual Dining, Pub                                        Pizza, Beer
# 51705   Bar, Casual Dining  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 51706                  Pub                                                NaN
# 51707     Fine Dining, Bar                                   Rooftop Ambience
# 51708   Casual Dining, Bar  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 51709   Casual Dining, Bar                                                NaN
# 51711   Casual Dining, Bar                               Biryani, Andhra Meal
# 51712                  Bar                                                NaN
# 51715                  Bar                       Cocktails, Pizza, Buttermilk
# 51716   Bar, Casual Dining                                                NaN
#
#                                                 cuisines cost_two  \
# 0                         North Indian, Mughlai, Chinese      800
# 1                            Chinese, North Indian, Thai      800
# 2                                 Cafe, Mexican, Italian      800
# 3                             South Indian, North Indian      300
# 4                               North Indian, Rajasthani      600
# 5                                           North Indian      600
# 6            North Indian, South Indian, Andhra, Chinese      800
# 7                                   Pizza, Cafe, Italian      600
# 8                             Cafe, Italian, Continental      700
# 9               Cafe, Mexican, Italian, Momos, Beverages      550
# 10                                                  Cafe      500
# 11                            Cafe, Italian, Continental      600
# 12                   Cafe, Chinese, Continental, Italian      500
# 13                                     Cafe, Continental      450
# 14                                Cafe, Mexican, Italian      800
# 15                                                  Cafe      650
# 16          Cafe, Fast Food, Continental, Chinese, Momos      800
# 17                                Chinese, Cafe, Italian      700
# 18                               Cafe, Italian, American      300
# 19                   Cafe, Chinese, Continental, Italian      400
# 20                            Cafe, French, North Indian      400
# 21                     Cafe, Pizza, Fast Food, Beverages      500
# 22                                       Cafe, Fast Food      900
# 23                    Italian, Fast Food, Cafe, European      600
# 24                                                  Cafe      300
# 25                                          Cafe, Bakery      600
# 26                                    Cafe, South Indian      200
# 27                            Cafe, Fast Food, Beverages      500
# 28                                       Cafe, Fast Food      550
# 29                North Indian, Cafe, Chinese, Fast Food      550
# ...                                                  ...      ...
# 51684                      Continental, BBQ, Finger Food    1,700
# 51685         Continental, European, BBQ, Chinese, Asian    2,400
# 51686                      American, North Indian, Salad    2,500
# 51687  Continental, Mediterranean, South Indian, Nort...    1,700
# 51688             Mughlai, North Indian, Biryani, Afghan    1,100
# 51689    North Indian, Italian, Finger Food, Continental    1,000
# 51690                       Asian, Continental, European    1,500
# 51691                                  American, Italian    1,800
# 51692                               Continental, Chinese    1,000
# 51693             Continental, North Indian, Finger Food    1,200
# 51694  American, North Indian, Chinese, Finger Food, ...    1,500
# 51695                          British, Continental, BBQ    1,600
# 51696                                 European, American    1,700
# 51697  Asian, Japanese, Vietnamese, Korean, Chinese, ...    1,800
# 51698  North Indian, South Indian, Continental, Ameri...    1,200
# 51699                           Asian, American, Mexican    1,200
# 51700                 Continental, North Indian, Italian    1,500
# 51701        Finger Food, North Indian, Chinese, Italian    1,400
# 51702              Finger Food, American, Asian, Italian    1,450
# 51703  Finger Food, American, Continental, Burger, Pizza    1,500
# 51704                       North Indian, Pizza, Chinese    1,500
# 51705           North Indian, Continental, Mediterranean    1,200
# 51706                          North Indian, Continental    1,200
# 51707                                        Finger Food    2,000
# 51708                 Chinese, Continental, North Indian    1,200
# 51709                          North Indian, Continental      800
# 51711        Andhra, South Indian, Chinese, North Indian      800
# 51712                                        Continental    1,500
# 51715                                        Finger Food    2,500
# 51716             Finger Food, North Indian, Continental    1,500
#
#                                             reviews_list  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...
# 3      [('Rated 4.0', "RATED\n  Great food and proper...
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...
# 5      [('Rated 3.0', 'RATED\n  Food 3/5\nAmbience 3/...
# 6      [('Rated 5.0', 'RATED\n  Awesome food ??Great ...
# 7      [('Rated 5.0', 'RATED\n  I personally really l...
# 8      [('Rated 3.0', "RATED\n  I had been to this pl...
# 9      [('Rated 4.0', "RATED\n  Easy to locate\nVFM 3...
# 10     [('Rated 4.0', 'RATED\n  We ended up here on a...
# 11     [('Rated 1.0', "RATED\n \n\nHorrible. Not even...
# 12     [('Rated 4.0', "RATED\n  Food - 4/5\nAmbience ...
# 13     [('Rated 2.0', "RATED\n  This is a hookah cafe...
# 14     [('Rated 3.0', "RATED\n  Ambience is not that ...
# 15     [('Rated 2.0', 'RATED\n  Not so good place as ...
# 16     [('Rated 1.0', "RATED\n  This place is right o...
# 17     [('Rated 3.0', "RATED\n  New place.. though it...
# 18     [('Rated 4.0', "RATED\n  Happy to see such a c...
# 19     [('Rated 5.0', 'RATED\n  Friendly staffs , nic...
# 20     [('Rated 2.0', "RATED\n  This is a tiny cafÃ\...
# 21     [('Rated 3.0', 'RATED\n  Decided to take a bre...
# 22     [('Rated 4.0', 'RATED\n  This outlet is better...
# 23     [('Rated 4.0', "RATED\n  So, went here with fr...
# 24     [('Rated 4.0', 'RATED\n  The food was quite go...
# 25     [('Rated 1.0', "RATED\n  No ventilation. Smoke...
# 26     [('Rated 5.0', 'RATED\n  please provide some e...
# 27     [('Rated 5.0', 'RATED\n  Newly opened cafe nea...
# 28     [('Rated 1.5', 'RATED\n  This place was good t...
# 29     [('Rated 5.0', 'RATED\n  No words for the pane...
# ...                                                  ...
# 51684  [('Rated 5.0', 'RATED\n  A very friendly place...
# 51685  [('Rated 3.0', 'RATED\n  We had been here on a...
# 51686  [('Rated 5.0', "RATED\n  A review for Windmill...
# 51687  [('Rated 4.0', 'RATED\n  Red Rhino is a Brewer...
# 51688  [('Rated 4.0', 'RATED\n  Was there on last Wed...
# 51689  [('Rated 3.0', "RATED\n  HQ is located at grou...
# 51690  [('Rated 3.0', 'RATED\n  Went with Team on Thu...
# 51691  [('Rated 4.0', "RATED\n  Had been here for lun...
# 51692  [('Rated 3.0', 'RATED\n  Amoeba is affordable ...
# 51693  [('Rated 4.0', 'RATED\n  Had been there on a S...
# 51694  [('Rated 2.0', 'RATED\n  Honestly speaking it ...
# 51695  [('Rated 4.0', "RATED\n  I never knew of this ...
# 51696  [('Rated 4.0', 'RATED\n  Nice place to grab a ...
# 51697  [('Rated 3.0', 'RATED\n  Wanted to try this pl...
# 51698  [('Rated 4.0', 'RATED\n  Loved the food, thoug...
# 51699  [('Rated 4.0', 'RATED\n  The first thing that ...
# 51700  [('Rated 4.0', "RATED\n  In an increasingly ov...
# 51701  [('Rated 2.0', "RATED\n  We went out to this p...
# 51702  [('Rated 4.0', 'RATED\n  A good place to dine....
# 51703  [('Rated 4.0', "RATED\n  I had :-\n\n1. Italia...
# 51704  [('Rated 3.0', 'RATED\n  Like this place for z...
# 51705  [('Rated 3.0', "RATED\n  Nice place to hangout...
# 51706  [('Rated 5.0', 'RATED\n  Excellent place had n...
# 51707  [('Rated 4.0', 'RATED\n  Went there post dinne...
# 51708  [('Rated 3.0', 'RATED\n  Place is good not tha...
# 51709  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...
#
#                                                menu_item   service_type  \
# 0                                                     []         Buffet
# 1                                                     []         Buffet
# 2                                                     []         Buffet
# 3                                                     []         Buffet
# 4                                                     []         Buffet
# 5                                                     []         Buffet
# 6                                                     []         Buffet
# 7                                                     []          Cafes
# 8                                                     []          Cafes
# 9                                                     []          Cafes
# 10                                                    []          Cafes
# 11                                                    []          Cafes
# 12                                                    []          Cafes
# 13                                                    []          Cafes
# 14                                                    []          Cafes
# 15                                                    []          Cafes
# 16                                                    []          Cafes
# 17                                                    []          Cafes
# 18                                                    []          Cafes
# 19                                                    []          Cafes
# 20                                                    []          Cafes
# 21                                                    []          Cafes
# 22                                                    []          Cafes
# 23                                                    []          Cafes
# 24                                                    []          Cafes
# 25                                                    []          Cafes
# 26                                                    []          Cafes
# 27                                                    []          Cafes
# 28                                                    []          Cafes
# 29                                                    []          Cafes
# ...                                                  ...            ...
# 51684                                                 []  Pubs and bars
# 51685                                                 []  Pubs and bars
# 51686                                                 []  Pubs and bars
# 51687  ['Hangover', 'Smoking Hot Red Rhino Chilli Chi...  Pubs and bars
# 51688  ['Dal Tadka', 'Dal Makhani', 'Paneer Tikka Mas...  Pubs and bars
# 51689                                                 []  Pubs and bars
# 51690                                                 []  Pubs and bars
# 51691                                                 []  Pubs and bars
# 51692                                                 []  Pubs and bars
# 51693  ['Chicken Manchow Soup', 'Chicken Lollipop', '...  Pubs and bars
# 51694  ['Chilli Paneer Black Pepper China Box', 'Chil...  Pubs and bars
# 51695                                                 []  Pubs and bars
# 51696                                                 []  Pubs and bars
# 51697                                                 []  Pubs and bars
# 51698                                                 []  Pubs and bars
# 51699                                                 []  Pubs and bars
# 51700                                                 []  Pubs and bars
# 51701                                                 []  Pubs and bars
# 51702                                                 []  Pubs and bars
# 51703                                                 []  Pubs and bars
# 51704                                                 []  Pubs and bars
# 51705                                                 []  Pubs and bars
# 51706                                                 []  Pubs and bars
# 51707                                                 []  Pubs and bars
# 51708                                                 []  Pubs and bars
# 51709                                                 []  Pubs and bars
# 51711                                                 []  Pubs and bars
# 51712                                                 []  Pubs and bars
# 51715                                                 []  Pubs and bars
# 51716                                                 []  Pubs and bars
#
#            serve_to
# 0      Banashankari
# 1      Banashankari
# 2      Banashankari
# 3      Banashankari
# 4      Banashankari
# 5      Banashankari
# 6      Banashankari
# 7      Banashankari
# 8      Banashankari
# 9      Banashankari
# 10     Banashankari
# 11     Banashankari
# 12     Banashankari
# 13     Banashankari
# 14     Banashankari
# 15     Banashankari
# 16     Banashankari
# 17     Banashankari
# 18     Banashankari
# 19     Banashankari
# 20     Banashankari
# 21     Banashankari
# 22     Banashankari
# 23     Banashankari
# 24     Banashankari
# 25     Banashankari
# 26     Banashankari
# 27     Banashankari
# 28     Banashankari
# 29     Banashankari
# ...             ...
# 51684    Whitefield
# 51685    Whitefield
# 51686    Whitefield
# 51687    Whitefield
# 51688    Whitefield
# 51689    Whitefield
# 51690    Whitefield
# 51691    Whitefield
# 51692    Whitefield
# 51693    Whitefield
# 51694    Whitefield
# 51695    Whitefield
# 51696    Whitefield
# 51697    Whitefield
# 51698    Whitefield
# 51699    Whitefield
# 51700    Whitefield
# 51701    Whitefield
# 51702    Whitefield
# 51703    Whitefield
# 51704    Whitefield
# 51705    Whitefield
# 51706    Whitefield
# 51707    Whitefield
# 51708    Whitefield
# 51709    Whitefield
# 51711    Whitefield
# 51712    Whitefield
# 51715    Whitefield
# 51716    Whitefield
#
# [41418 rows x 14 columns]

# %%
#Find the unique values of cost_two and data type of cost_two variable
zom["cost_two"].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '1,100', '1,600', '230',
#        '130', '1,700', '1,350', '2,200', '1,400', '2,000', '1,800',
#        '1,900', '180', '330', '2,500', '2,100', '3,000', '2,800', '3,400',
#        '50', '40', '1,250', '3,500', '4,000', '2,400', '2,600', '1,450',
#        '70', '3,200', '240', '6,000', '1,050', '2,300', '4,100', '120',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '80'], dtype=object)

# %% [markdown]
# To convert the variable to an integer we could simply use `astype('int')` but in this scenario, this method would not work because of the presence of a comma in between the numbers, eg. 2,500. To avoid this kind of problem, we are using `lambda` and `replace` function to replace comma (,) with nothing and then convert to integer.

# %%
#converting the cost_two variable to int
#apply the lambda function on cost_two column and convert to int().
#remember to replace any string values present in the entries of this column before converting to numeric, you can do it in the same lambda function line
#then again check the data
zom["cost_two"]=zom["cost_two"].apply(lambda x: int(x.replace(",","")))

# %%
zom["cost_two"].unique()
# Out:
# array([ 800,  300,  600,  700,  550,  500,  450,  650,  400,  900,  200,
#         750,  150,  850,  100, 1200,  350,  250,  950, 1000, 1500, 1300,
#         199, 1100, 1600,  230,  130, 1700, 1350, 2200, 1400, 2000, 1800,
#        1900,  180,  330, 2500, 2100, 3000, 2800, 3400,   50,   40, 1250,
#        3500, 4000, 2400, 2600, 1450,   70, 3200,  240, 6000, 1050, 2300,
#        4100,  120, 5000, 3700, 1650, 2700, 4500,   80], dtype=int64)

# %% [markdown]
# __4. Visualization__
#
# In this section, we will analyze the data by creating multiple visualizations using seaborn and matplotlib.
# you can use `plt.rcParams['figure.figsize'] = 14,7` for fixing the figure size

# %%
plt.rcParams['figure.figsize']=14,7

# %%
sns.distplot?

# %%
#lets plot the distribution of votes, Use sns.distplot()
sns.distplot(zom["votes"],kde=False,bins=5)
plt.ylabel("Count")
plt.title("Distribution of votes")
# Out:
# Text(0.5, 1.0, 'Distribution of votes')

# %% [markdown]
# __Q. WHat does this distplot shows about the distribution of votes?
# _Ans.___ Majority of the votes lie between 0 to 3000 range. It might be following exponential distribution.

# %% [markdown]
# ###### a. Count Plot
# Countplot is essentially the same as the barplot except that it shows the count of observations in each category bin using bars. In our dataset, let’s check the count of each rating category present.

# %%
#plot the count of rating. use sns.countplot() with palette="Set1"
sns.countplot(zom["rate"],palette="Set1")

# %% [markdown]
# __Q. WHat does this countplot shows about the distribution of `rate`? what distribution it is following , what could be mean values? what is the rating range for majority of the restaurants? Any other obseravtion?
# _Ans.__ _The 'rate' follows a bell shaped distribution. It seems like it follows normal distribution. The mean could be 3.7 or 3.8 . The rating range for majority of the customers is 3.7-3.9.

# %% [markdown]
# ###### b. Joint Plot
#
# Jointplot allows us to compare the two different variables and see if there is any relationship between these two variables. By using the Joint plot we can do both bivariate and univariate analysis by plotting the scatterplot (bivariate) and distribution plot (univariate) of two different variables in a single plotting grid.

# %%
#joint plot for 'rate' and 'votes'. use sns.jointplot(). For displaying you csn use plt.show() also
sns.jointplot("rate","votes",zom)
# Out:
# L:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# __Q. What we can infer from the above plot?__
# ___Ans:___ There is positive relation between the votes and rate. As the ratings increase the votes also increase

# %% [markdown]
# ###### c. Bar Plot
#
# Barplot is one of the most commonly used graphic to represent the data. Barplot represents data in rectangular bars with length of the bar proportional to the value of the variable. We will analyze the variable location and see in which area most of the restaurants are located in Bangalore.

# %%
zom.plot?

# %%
zom["location"].value_counts()
# Out:
# BTM                           3906
# Koramangala 5th Block         2297
# HSR                           2004
# Indiranagar                   1803
# JP Nagar                      1717
# Jayanagar                     1636
# Whitefield                    1577
# Marathahalli                  1428
# Bannerghatta Road             1230
# Koramangala 6th Block         1069
# Koramangala 7th Block         1055
# Brigade Road                  1052
# Bellandur                     1012
# Sarjapur Road                  860
# Koramangala 1st Block          852
# Ulsoor                         849
# Koramangala 4th Block          841
# Electronic City                840
# MG Road                        793
# Banashankari                   744
# Kalyan Nagar                   695
# Malleshwaram                   641
# Richmond Road                  604
# Residency Road                 604
# Basavanagudi                   595
# Frazer Town                    566
# Church Street                  546
# Brookefield                    543
# New BEL Road                   506
# Kammanahalli                   498
#                               ...
# ITPL Main Road, Whitefield      78
# City Market                     75
# Hosur Road                      72
# Vijay Nagar                     62
# CV Raman Nagar                  61
# RT Nagar                        60
# Sadashiv Nagar                  58
# Sanjay Nagar                    48
# Sahakara Nagar                  45
# Koramangala                     30
# East Bangalore                  28
# Langford Town                   27
# Rammurthy Nagar                 26
# Sankey Road                     26
# Magadi Road                     24
# Jalahalli                       23
# Old Madras Road                 22
# Kanakapura Road                 19
# Mysore Road                     17
# KR Puram                        10
# North Bangalore                 10
# Uttarahalli                      9
# Kengeri                          9
# Central Bangalore                8
# Hebbal                           8
# Yelahanka                        4
# West Bangalore                   3
# Rajarajeshwari Nagar             2
# Nagarbhavi                       1
# Peenya                           1
# Name: location, Length: 92, dtype: int64

# %%
#analyze the number of restaurants in a location. Use general plot() method
zom["location"].value_counts().plot(kind="barh",)

# %% [markdown]
# __Q. What we can infer from the above plot?__
# ___Ans:___ The location BTM has the most number of restaurants

# %% [markdown]
# ##### d. Correlation Heatmap
#
# Correlation describes how strongly a pair of variables are related to each other.

# %%
#seaborn heatmap function to plot the correlation grid
sns.heatmap(zom.corr(), annot = True, cmap = "viridis",linecolor='white',linewidths=1)
plt.show()

# %% [markdown]
# The correlation function `corr` calculates the Pearson correlation between the numeric variables, it has a value between +1 and −1, where 1 is a total positive linear correlation, 0 is no linear correlation, and −1 is a total negative linear correlation.

# %% [markdown]
# __Q. What we can infer from the above plot?__
# ___Ans:___ book_table and cost_two are moderately positively correlated. votes and rate are also moderately correlated.

# %% [markdown]
# ##### Restaurant Listed in
# Lets see to in which area most of the restaurants are listed in or deliver to.

# %%
zom.plot?

# %%
#restaurants serve to. use serve_to column and create frequency bar plot
#however, you can use countplot also. but, then graph will look different than below.
#Infer according to your plot
zom["serve_to"].value_counts().plot(kind="barh",color="blue")
plt.ylabel("Serve to")
plt.xlabel("Count")
plt.title("Number of restaurants serving a location ")
# Out:
# Text(0.5, 1.0, 'Number of restaurants serving a location ')

# %% [markdown]
# __Q. What we can infer from the above plot?__
# ___Ans:___ The BTM region is the most served locations by restaurants.

# %% [markdown]
# ###### Online Order
# Analyzing the restaurants based on availability of online order facility

# %%
#count plot for online_order analysis
sns.countplot(zom["online_order"])
plt.xlabel("Online_order")
plt.ylabel("Count")
plt.title(" Availibility of online order")
# Out:
# Text(0.5, 1.0, ' Availibility of online order')

# %% [markdown]
# __Q. What we can infer from the above plot?__
# ___Ans:___ More restaurants offer the facility of online food ordering.

# %% [markdown]
# *__Does online order facility impacts the rating of the restaurant?__*

# %%
sns.countplot(hue = zom["online_order"], palette = "Set1", x = zom["rate"])
plt.title("Distribution of restaurant rating over online order facility")
plt.show()

# %% [markdown]
# Restaurants which provide online order facility has better ratings than the traditional restaurants. It makes sense because many software employees stay in Bangalore and they tend to order a lot of food through the online.

# %% [markdown]
# ##### Booking Table

# %%
#rating vs booking table
sns.countplot(hue = zom["book_table"], palette = "Set2", x = zom["rate"])
plt.title("Distribution of restaurant rating over booking table facility")
plt.show()

# %%
#Use catplot() to combine a countplot() and a FacetGrid. This allows grouping within additional categorical variables
g = sns.catplot(x="book_table", hue="service_type", col="online_order", data=zom, kind="count")

# %% [markdown]
# - Most of the highly rated restaurants (rating more than 4.0) provide an option of booking table

# %% [markdown]
# ##### Restaurant Service Type

# %%
#check the restaurant service type

zom.service_type.value_counts().plot(kind = "pie", autopct='%.1f%%')
plt.show()

# %% [markdown]
# - Majority of restaurants (~>50%) provides an option of home delivery.
# - 35% of the restaurants listed on Zomato provides Dine out option

# %% [markdown]
# ##### Does the service type effects ratings given to the restaurant?

# %%
#ratings vs service type
sns.boxplot(x="service_type", y="rate", data = zom)
plt.show()

# %% [markdown]
# - The Restaurants which serve drinks (pubs and bars) has median rating more than 4.5 but from the violin plot we can see that thse restaurants receive very few ratings compared to other type of restaurants

# %% [markdown]
# ###### Biggest Restaurant Chain and Best Restaurant Chain

# %%
plt.rcParams['figure.figsize'] = 14,7
plt.subplot(1,2,1)
zom.name.value_counts().head().plot(kind = "barh", color = sns.color_palette("hls", 5))
plt.xlabel("Number of restaurants")
plt.title("Biggest Restaurant Chain (Top 5)")

plt.subplot(1,2,2)
zom[zom['rate']>=4.5]['name'].value_counts().nlargest(5).plot(kind = "barh", color = sns.color_palette("Paired"))
plt.xlabel("Number of restaurants")
plt.title("Best Restaurant Chain (Top 5) - Rating More than 4.5")
plt.tight_layout()

# %% [markdown]
# Cafe Coffee Day chain has over 90 cafes across the city that are listed in Zomato. On the other hand, Truffles – a burger chain has the best fast food restaurants (rating more than 4.5 out of 100), quality over quantity.
#
# Next time when you visit Bangalore or if you want to check out a good restaurant over a weekend don’t forget to try the food at **Truffles**, **Hammered** and **Mainland China**.

# %% [markdown]
# ##### Top Restaurant Type

# %%
plt.rcParams['figure.figsize'] = 14,7
zom.rest_type.value_counts().nlargest(10).plot(kind = "barh", color = sns.color_palette("hls", 10))
plt.xlabel("Count")
plt.title("Top Restaurant Type (Top 10)")
plt.show()

# %% [markdown]
# Hope, You have enjoyed this case study, and have learned few aspects of EDA (Exploratory Data Analysis).
#
# ___Thank You!___
